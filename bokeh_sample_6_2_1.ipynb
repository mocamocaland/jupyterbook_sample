# %%
#　高レベルのインターフェースを使用したグラフ
#from bkcharts import Line
from bokeh.charts import Line, output_notebok, show

'''
output_notebook()
p = line([1, 2], plot_width=200, plot_height=200)
show(p)
'''
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-42514b360725> in <module>()
#       1 #　高レベルのインターフェースを使用したグラフ
#       2 #from bkcharts import Line
# ----> 3 from bokeh.charts import Line, output_notebok, show
#       4
#       5 '''
#
# ModuleNotFoundError: No module named 'bokeh.charts'

# %%
# 中レベルのインターフェースを使用グラフ
from bokeh.plotting import output_notebook, figure, show

output_notebook()
p = figure(plot_width=200, plot_height=200)
p.line([1, 2], [1, 2])
p.circle([1.5], [1.5])
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e65bc724-8b2b-4d61-9345-f82c82412cb1">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b2ca0ba0-7455-4bc5-9719-b373ddecf86a"></div>
# </div>

# %%
# 低レベル
from bokeh.plotting import output_notebook, figure, show
from bokeh.models import LinearAxis, Range1d

output_notebook()
p = figure(width=300, height=300, toolbar_location='above')
p.extra_y_ranges = {"small_data": Range1d(start=0, end=5)}
p.line([1, 2, 3],[1, 2, 3], y_range_name="small_data")
p.circle([1, 2, 3], [2000, 3000, 1000])
p.add_layout(LinearAxis(y_range_name="small_data"), 'right')
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b7f00175-a0b0-4596-b8a6-16b2b8a8231e">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="f088179c-8bf1-4e08-99d7-84a37578bbee"></div>
# </div>
