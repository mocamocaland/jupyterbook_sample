# %%
# 中レベルのインターフェースを使用グラフ
from bokeh.plotting import output_notebook, figure, show

output_notebook()
p = figure(plot_width=200, plot_height=200)
p.line([1, 2], [1, 2])
p.circle([1.5], [1.5])
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4390fc17-412d-48d0-8c01-fc7801f5dc08">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="feeea598-6020-4587-812a-7256a7a9e6e8"></div>
# </div>

# %%
# 低レベル
from bokeh.plotting import output_notebook, figure, show
from bokeh.models import LinearAxis, Range1d

output_notebook()
p = figure(width=300, height=300, toolbar_location='above')
p.extra_y_ranges = {"small_data": Range1d(start=0, end=5)}
p.line([1, 2, 3],[1, 2, 3], y_range_name="small_data")
p.circle([1, 2, 3], [2000, 3000, 1000])
p.add_layout(LinearAxis(y_range_name="small_data"), 'right')
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c2e95f80-56ad-4cfb-87a9-8b9e7becf189">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="878a41dc-6d80-49ed-bde9-69bad506d657"></div>
# </div>

# %%
from bokeh.io import reset_output

reset_output()
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8f01e523-c7a5-4741-bbf9-b0749f3ab820">Loading BokehJS ...</span>
#     </div>
