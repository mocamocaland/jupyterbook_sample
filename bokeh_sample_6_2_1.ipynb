# %%
#　高レベルのインターフェースを使用したグラフ
#from bkcharts import Line
#from bokeh.charts import Line, output_notebook, show
from bokeh.io import output_notebook, show #

'''
output_notebook()
p = line([1, 2], plot_width=200, plot_height=200)
show(p)
'''
# Out:
# '\noutput_notebook()\np = line([1, 2], plot_width=200, plot_height=200)\nshow(p)\n'

# %%
# 中レベルのインターフェースを使用グラフ
from bokeh.plotting import output_notebook, figure, show

output_notebook()
p = figure(plot_width=200, plot_height=200)
p.line([1, 2], [1, 2])
p.circle([1.5], [1.5])
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0e072ea7-9fcd-4670-b01d-be326f31fbed">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="80b59377-15d8-47c0-83f3-9269f44d70b8"></div>
# </div>

# %%
# 低レベル
from bokeh.plotting import output_notebook, figure, show
from bokeh.models import LinearAxis, Range1d

output_notebook()
p = figure(width=300, height=300, toolbar_location='above')
p.extra_y_ranges = {"small_data": Range1d(start=0, end=5)}
p.line([1, 2, 3],[1, 2, 3], y_range_name="small_data")
p.circle([1, 2, 3], [2000, 3000, 1000])
p.add_layout(LinearAxis(y_range_name="small_data"), 'right')
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="516140fa-a17d-4d7a-8f5c-9b11bd3fa016">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="20fe91c4-eca1-43f1-b02d-341fb69d44ba"></div>
# </div>
