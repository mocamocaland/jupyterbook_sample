# %%
# 中レベルのインターフェースを使用グラフ
from bokeh.plotting import output_notebook, figure, show

output_notebook()
p = figure(plot_width=200, plot_height=200)
p.line([1, 2], [1, 2])
p.circle([1.5], [1.5])
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ae481742-2e2e-4e58-9737-b4171695d34c">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1d85b727-be97-426e-be2f-05bbaecfcb7d"></div>
# </div>

# %%
# 低レベル
from bokeh.plotting import output_notebook, figure, show
from bokeh.models import LinearAxis, Range1d

output_notebook()
p = figure(width=300, height=300, toolbar_location='above')
p.extra_y_ranges = {"small_data": Range1d(start=0, end=5)}
p.line([1, 2, 3],[1, 2, 3], y_range_name="small_data")
p.circle([1, 2, 3], [2000, 3000, 1000])
p.add_layout(LinearAxis(y_range_name="small_data"), 'right')
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="23289a15-3b93-4949-b2dc-8dff20f75917">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="5151e3ea-8340-4cde-b9cd-a10416c77c8a"></div>
# </div>

# %%
from bokeh.io import reset_output

reset_output()
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f8e0d075-619c-4c48-bc26-a5638ed2d017">Loading BokehJS ...</span>
#     </div>
