# %%
from bokeh.plotting import figure, output_notebook, show

output_notebook()

# 軸の書式の設定
p = figure(plot_width=200, plot_height=200)
r = p.circle([0], [0])
p.xaxis.axis_label = 'x'
p.yaxis.axis_label = 'y'
p.xaxis.axis_label_text_color = 'red'
p.axis.axis_line_width = 3
p.xaxis.axis_line_dash = 'dashed'
p.xaxis.axis_label_standoff = 30
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e34db2c7-e323-412c-8396-fdecc097fe96">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="89b016b1-9fd3-4aa2-bad1-c0387bc57e5a"></div>
# </div>

# %%
#　軸の幅の設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.yaxis.bounds = (-0.5, 0.5)
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="0ec8ea2d-053d-4925-83a1-3a596b5ddbdb"></div>
# </div>

# %%
#目盛りの書式の設定

p = figure(plot_width=200, plot_height=200)

p.circle([0], [0])
p.xaxis.major_tick_line_width = 3
p.yaxis.major_tick_line_color = 'red'
p.yaxis.major_tick_line_color = 'blue'
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="768f0558-fca5-4771-a273-9c2cdc8cc587"></div>
# </div>

# %%
#以下chartsのためサンプルなし
