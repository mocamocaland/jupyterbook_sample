# %%
import os
import pandas as pd
import numpy as np

# %%
base_url = 'http://raw.githubusercontent.com/practical-jupyter/sample-data/master/anime/'
anime_master_csv = os.path.join(base_url, 'anime_master.csv')
df = pd.read_csv(anime_master_csv)
df
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                           Gintama'
# 5         32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6         11061                             Hunter x Hunter (2011)
# 7           820                               Ginga Eiyuu Densetsu
# 8         15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 9         15417                                Gintama': Enchousen
# 10         4181                               Clannad: After Story
# 11        28851                                     Koe no Katachi
# 12          918                                            Gintama
# 13         2904                 Code Geass: Hangyaku no Lelouch R2
# 14        28891                            Haikyuu!! Second Season
# 15          199                      Sen to Chihiro no Kamikakushi
# 16        23273                            Shigatsu wa Kimi no Uso
# 17        24701                      Mushishi Zoku Shou 2nd Season
# 18        12355                       Ookami Kodomo no Ame to Yuki
# 19         1575                    Code Geass: Hangyaku no Lelouch
# 20          263                                     Hajime no Ippo
# 21           44  Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...
# 22            1                                       Cowboy Bebop
# 23        30276                                      One Punch Man
# 24          164                                      Mononoke Hime
# 25         7311                      Suzumiya Haruhi no Shoushitsu
# 26        17074                   Monogatari Series: Second Season
# 27        21939                                 Mushishi Zoku Shou
# 28          457                                           Mushishi
# 29         2001                         Tengen Toppa Gurren Lagann
# ...         ...                                                ...
# 10045     31838                                         Ze Tian Ji
# 10046     33048                                       Zegapain ADP
# 10047     30211                                      Zenchuu Maite
# 10048      5821                                     Zenmai Zamurai
# 10049      4790                             Zeno: Kagirinaki Ai ni
# 10050     33571                       Zenryoku Yobikou 5.5 Seminar
# 10051     33570              Zenryoku Yobikou 5.5 Seminar Prologue
# 10052      9520                                        Zero Tester
# 10053      9522                    Zero Tester: Chikyuu wo Mamore!
# 10054     23313                   Zettai Zetsumei Dangerous Jiisan
# 10055     10987            Zettai Zetsumei Dangerous Jiisan (2004)
# 10056     22709            Zettai Zetsumei Dangerous Jiisan (2005)
# 10057     23315       Zettai Zetsumei Dangerous Jiisan Special-ban
# 10058     31698                                    Zhan Long Si Qu
# 10059     33339                          Zhongguo Jingqi Xiansheng
# 10060     11093                          Ziggy: Soreyuke! R&R Band
# 10061     31427                                              Zinba
# 10062     32733       ZIP! x Peeping Life TV: Cool Japan Saizensen
# 10063     19717                             Zoku Naniwa Yuukyouden
# 10064     12759                       Zoku Zoku Mura no Obaketachi
# 10065     32557                 Zombie Clay Animation: I'm Stuck!!
# 10066     30089            Zombie Clay Animation: Life of the Dead
# 10067     30090                                        Zombie Ehon
# 10068     13167                                           Zoobles!
# 10069     11097                             Zou no Inai Doubutsuen
# 10070     11095                            Zouressha ga Yatte Kita
# 10071      7808                   Zukkoke Knight: Don De La Mancha
# 10072     28543  Zukkoke Sannin-gumi no Hi Asobi Boushi Daisakusen
# 10073     18967          Zukkoke Sannin-gumi: Zukkoke Jikuu Bouken
# 10074     13455                                   Zumomo to Nupepe
#
#                                                    genre     type  episodes  \
# 0                   Drama, Romance, School, Supernatural    Movie         1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...       TV        64
# 2      Action, Comedy, Historical, Parody, Samurai, S...       TV        51
# 3                                       Sci-Fi, Thriller       TV        24
# 4      Action, Comedy, Historical, Parody, Samurai, S...       TV        51
# 5                 Comedy, Drama, School, Shounen, Sports       TV        10
# 6                Action, Adventure, Shounen, Super Power       TV       148
# 7                         Drama, Military, Sci-Fi, Space      OVA       110
# 8      Action, Comedy, Historical, Parody, Samurai, S...    Movie         1
# 9      Action, Comedy, Historical, Parody, Samurai, S...       TV        13
# 10     Drama, Fantasy, Romance, Slice of Life, Supern...       TV        24
# 11                                Drama, School, Shounen    Movie         1
# 12     Action, Comedy, Historical, Parody, Samurai, S...       TV       201
# 13     Action, Drama, Mecha, Military, Sci-Fi, Super ...       TV        25
# 14                Comedy, Drama, School, Shounen, Sports       TV        25
# 15                        Adventure, Drama, Supernatural    Movie         1
# 16                Drama, Music, Romance, School, Shounen       TV        22
# 17     Adventure, Fantasy, Historical, Mystery, Seine...       TV        10
# 18                                Fantasy, Slice of Life    Movie         1
# 19     Action, Mecha, Military, School, Sci-Fi, Super...       TV        25
# 20                        Comedy, Drama, Shounen, Sports       TV        75
# 21     Action, Drama, Historical, Martial Arts, Roman...      OVA         4
# 22       Action, Adventure, Comedy, Drama, Sci-Fi, Space       TV        26
# 23     Action, Comedy, Parody, Sci-Fi, Seinen, Super ...       TV        12
# 24                            Action, Adventure, Fantasy    Movie         1
# 25     Comedy, Mystery, Romance, School, Sci-Fi, Supe...    Movie         1
# 26       Comedy, Mystery, Romance, Supernatural, Vampire       TV        26
# 27     Adventure, Fantasy, Historical, Mystery, Seine...       TV        10
# 28     Adventure, Fantasy, Historical, Mystery, Seine...       TV        26
# 29              Action, Adventure, Comedy, Mecha, Sci-Fi       TV        27
# ...                                                  ...      ...       ...
# 10045                         Action, Adventure, Fantasy      ONA        13
# 10046                     Action, Mecha, Romance, Sci-Fi    Movie         1
# 10047                                           Dementia    Movie         1
# 10048                                       Comedy, Kids       TV        30
# 10049                                  Drama, Historical    Movie         1
# 10050                             Comedy, Parody, School      ONA         9
# 10051                             Comedy, Parody, School      ONA         1
# 10052                   Action, Adventure, Mecha, Sci-Fi       TV        38
# 10053                   Action, Adventure, Mecha, Sci-Fi       TV        28
# 10054                                       Comedy, Kids       TV        33
# 10055                                       Comedy, Kids       TV        51
# 10056                                       Comedy, Kids       TV        19
# 10057                                       Comedy, Kids  Special         1
# 10058                                         Cars, Kids       TV        64
# 10059                     Comedy, Supernatural, Thriller      ONA        63
# 10060                          Adventure, Music, Mystery    Movie         1
# 10061  Action, Adventure, Comedy, Demons, Magic, Supe...       TV        52
# 10062                              Comedy, Slice of Life      ONA         5
# 10063                                     Action, Comedy      OVA         1
# 10064                                            Fantasy      OVA        12
# 10065                                     Comedy, Horror      ONA         4
# 10066                                     Comedy, Horror      OVA         4
# 10067                                             Comedy      ONA         1
# 10068                                               Kids       TV        26
# 10069                                              Drama    Movie         1
# 10070                                          Adventure    Movie         1
# 10071             Adventure, Comedy, Historical, Romance       TV        23
# 10072                                        Drama, Kids      OVA         1
# 10073                         Comedy, Historical, Sci-Fi      OVA         1
# 10074                                             Comedy       TV        32
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# 5        9.15    93351
# 6        9.13   425855
# 7        9.11    80679
# 8        9.10    72534
# 9        9.11    81109
# 10       9.06   456749
# 11       9.05   102733
# 12       9.04   336376
# 13       8.98   572888
# 14       8.93   179342
# 15       8.93   466254
# 16       8.92   416397
# 17       8.88    75894
# 18       8.84   226193
# 19       8.83   715151
# 20       8.83   157670
# 21       8.83   129307
# 22       8.82   486824
# 23       8.82   552458
# 24       8.81   339556
# 25       8.81   240297
# 26       8.80   205959
# 27       8.80   101351
# 28       8.78   300030
# 29       8.78   562962
# ...       ...      ...
# 10045    6.80      180
# 10046    6.35     1859
# 10047    4.27       73
# 10048    6.44      152
# 10049    6.76      207
# 10050    5.00       46
# 10051    4.73       62
# 10052    6.43      181
# 10053    5.23      137
# 10054    5.82       76
# 10055    6.55      135
# 10056    7.00       66
# 10057    6.80       57
# 10058    4.80       67
# 10059    6.96      386
# 10060    6.45      123
# 10061    7.17      172
# 10062    5.38       60
# 10063    5.10       78
# 10064    6.33       76
# 10065    4.33       72
# 10066    4.95      125
# 10067    3.54       86
# 10068    5.57      109
# 10069    6.07       85
# 10070    6.06       78
# 10071    6.47      172
# 10072    5.83       50
# 10073    6.13       76
# 10074    7.00      120
#
# [10075 rows x 7 columns]

# %%
grouped = df.groupby('type')
type(grouped)
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
grouped.mean().round(1)
# Out:
#          anime_id  episodes  rating  members
# type
# Movie     14322.5       1.1     6.3  10654.0
# Music     22495.1       1.1     5.6   1273.0
# ONA       22738.0       6.8     5.6   4401.8
# OVA       12207.7       2.5     6.5   6849.5
# Special   16802.3       2.5     6.5   7424.6
# TV        10929.6      37.5     6.9  41832.3

# %%
grouped.describe().round(1).head(16)
# Out:
#         anime_id                                                               \
#            count     mean      std    min      25%      50%      75%      max
# type
# Movie     2220.0  14322.5  10925.7    5.0   4396.8  10677.5  24071.5  34201.0
# Music      485.0  22495.1  10175.0  731.0  12101.0  24903.0  31925.0  34412.0
# ONA        591.0  22738.0  10346.0  574.0  13467.0  25241.0  32287.5  34514.0
# OVA       1932.0  12207.7  10718.7   44.0   2297.2   8965.5  22459.5  34349.0
# Special   1517.0  16802.3  10838.8  191.0   6877.0  15815.0  27821.0  34519.0
# TV        3330.0  10929.6  10645.4    1.0   2112.2   6511.5  18938.5  34503.0
#
#         episodes        ...   members             rating                      \
#            count  mean  ...       75%        max   count mean  std  min  25%
# type                    ...
# Movie     2220.0   1.1  ...    4239.0   466254.0  2220.0  6.3  1.2  2.5  5.4
# Music      485.0   1.1  ...     797.0    71136.0   485.0  5.6  1.0  3.3  5.0
# ONA        591.0   6.8  ...    1890.5   144898.0   591.0  5.6  1.1  2.7  4.9
# OVA       1932.0   2.5  ...    5706.0   305165.0  1932.0  6.5  0.9  2.0  5.9
# Special   1517.0   2.5  ...    6978.0   160423.0  1517.0  6.5  0.9  1.7  6.1
# TV        3330.0  37.5  ...   41568.2  1013917.0  3330.0  6.9  0.8  3.0  6.5
#
#
#          50%  75%   max
# type
# Movie    6.5  7.3  10.0
# Music    5.6  6.2   8.4
# ONA      5.7  6.4   8.3
# OVA      6.5  7.1   9.2
# Special  6.6  7.1   8.7
# TV       7.0  7.5   9.3
#
# [6 rows x 32 columns]

# %%
df.groupby(['type', 'episodes']).mean().round(1).head(20)
#       365       14566.000000     841.500000  6.195000
#       366         269.000000  624055.000000  7.950000
#       373        3545.000000    4734.000000  7.820000
#       475       31517.000000     146.000000  5.500000
#       510        7981.000000     161.000000  6.540000
#       526       11595.000000     447.000000  6.340000
#       694        4936.000000    2116.000000  6.920000
#       726        9768.000000     237.000000  6.250000
#       773       20117.000000     110.000000  5.630000
#       1006      10241.000000     153.000000  5.920000
#       1274      22221.000000     112.000000  6.800000
#       1306      32448.000000      59.000000  6.430000
#       1428       8213.000000     194.000000  6.050000
#       1471       6277.000000     406.000000  6.480000
#       1565      23349.000000     116.000000  5.560000
#       1787       2471.000000   14233.000000  7.760000
#       1818      12393.000000     160.000000  6.180000
#
# [291 rows x 3 columns]

# %%
# genre列のカンマ区切りのデーターを分割
genres = df['genre'].map(lambda x: x.split(','))
#numpy.arrayにして2次元から1次元のデータに変換
ser = pd.Series(np.hstack(genres.values))

#ユニークにする
unique_genres = ser.str.strip().unique()
unique_genres.sort()
unique_genres
# Out:
# array(['Action', 'Adventure', 'Cars', 'Comedy', 'Dementia', 'Demons',
#        'Drama', 'Fantasy', 'Game', 'Harem', 'Historical', 'Horror',
#        'Josei', 'Kids', 'Magic', 'Martial Arts', 'Mecha', 'Military',
#        'Music', 'Mystery', 'Parody', 'Police', 'Psychological', 'Romance',
#        'Samurai', 'School', 'Sci-Fi', 'Seinen', 'Shoujo', 'Shoujo Ai',
#        'Shounen', 'Shounen Ai', 'Slice of Life', 'Space', 'Sports',
#        'Super Power', 'Supernatural', 'Thriller', 'Vampire'], dtype=object)

# %%
#指定したジャンル名をDataFrameから抽出
def fileter_df_by_genre(df, genre):
    genre_df = df.loc[df['genre'].map(lambda x: genre in x)].copy()
    genre_df['genre'] = genre
    return genre_df

#上記の関数を全てのジャンルに対して実行
genre_df_list = [fileter_df_by_genre(df, genre) for genre in unique_genres]
# 上記dataを結合
df2 = pd.concat(genre_df_list)
# name列でソート
df2.sort_values('name', inplace=True)

#メンバ数が多いジャンルトップ10
top10 = df2.groupby('genre')['members'].sum().sort_values(
    ascending=False).index[:10]
# top10からデータを抽出
df2 = df2[df2['genre'].isin(top10)]

# %%
df2.loc[df2['name'] == 'Kimi no Na wa.']
# Out:
#    anime_id            name         genre   type  episodes  rating  members
# 0     32281  Kimi no Na wa.  Supernatural  Movie         1    9.37   200630
# 0     32281  Kimi no Na wa.         Drama  Movie         1    9.37   200630
# 0     32281  Kimi no Na wa.       Romance  Movie         1    9.37   200630
# 0     32281  Kimi no Na wa.        School  Movie         1    9.37   200630

# %%
df2.pivot_table(index='genre', columns='type',
               values=['members'], aggfunc=np.sum).head()
# Out:
#               members
# type            Movie     Music        ONA        OVA    Special          TV
# genre
# Action     10224960.0   77054.0   524907.0  5793680.0  3412689.0  63364032.0
# Adventure   9485223.0   42829.0    70431.0  2373765.0  2052024.0  27529975.0
# Comedy      7293127.0   20860.0  1477266.0  5614758.0  6659293.0  65420862.0
# Drama       9034099.0  100734.0   188427.0  3043374.0  1915578.0  41011557.0
# Fantasy     8019406.0   43962.0   188937.0  2754224.0  2504131.0  34932563.0
